# %%
hungry=False
if hungry:
    print('Feed the dog!!')
else:
    print('Dont feed the dog!!')
# Out:
# Dont feed the dog!!

# %%
v='car'
if v=='car':
    print('Its a four wheeler')
elif v=='bike':
    print('Its a two wheeler')
else:
    print('idk')
# Out:
# Its a four wheeler
