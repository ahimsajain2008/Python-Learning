# %%
1<2 and 2<3
# Out:
# True

# %%
1<2 and 3<2
# Out:
# False

# %%
1>2 and 2>3
# Out:
# False

# %%
1<2 or 2<3
# Out:
# True

# %%
1<2 or 3<2
# Out:
# True

# %%
1>2 or 2>3
# Out:
# False

# %%
not (4>5)
# Out:
# True

# %%
not(5<6)
# Out:
# False
