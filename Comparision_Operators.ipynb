# %%
2==2
# Out:
# True

# %%
1==2
# Out:
# False

# %%
'Hello'=='bye'
# Out:
# False

# %%
'Bye'=='bye'
# Out:
# False

# %%
'20'==20
# Out:
# False

# %%
2.0==2
# Out:
# True

# %%
2!=1   #!= reffers to not equal
# Out:
# True

# %%
2!=2
# Out:
# False

# %%
'Hello'!='hello'
# Out:
# True
